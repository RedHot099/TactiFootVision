# %%
# !cat data/datasets/football_yolo/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../valid/images
#
# nc: 4
# names: ["ball", "goalkeeper", "player", "referee"]

# %%
from ultralytics import YOLO
from rfdetr import RFDETRBase

model_path = 'results/yolo12x/training/detect_yolo12x_run/weights/best.pt'
data_path = 'data/datasets/football_yolo/data.yaml'

model = RFDETRBase(model_path)
results = model.val(data=data_path)
# Out:
# Ultralytics 8.3.98 🚀 Python-3.12.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# YOLOv12x summary (fused): 283 layers, 59,047,964 parameters, 0 gradients, 198.5 GFLOPs
# val: Scanning /home/kuba/projects/tactifoot_vision/data/datasets/football_yolo/valid/labels.cache... 193 images, 0 backgrounds, 0 corrupt: 100%|██████████| 193/193 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.09it/s]
#                    all        193       3868      0.829      0.797      0.795      0.474
#                   ball        164        197      0.774       0.47       0.51        0.2
#             goalkeeper         63         63      0.766      0.873      0.826       0.52
#                 player        193       3414      0.915      0.921      0.943       0.63
#                referee         76        194      0.861      0.923      0.902      0.546
# ...
